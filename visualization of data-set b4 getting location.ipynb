# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
uni = pd.read_csv('university names .csv')

# %%
uni.head()
# Out:
#    ID                  university names country code
# 0   1               New York University          USA
# 1   2              Princeton University          USA
# 2   3               Stanford University          USA
# 3   4  University of Wisconsin, Madison          USA
# 4   5                Cornell University          USA

# %%
uni.nunique()
# Out:
# ID                  5891
# university names    5891
# country code         149
# dtype: int64

# %%
uni['country code'].unique()
# Out:
# array(['USA', 'GBR', 'ARE', 'UKR', 'TUR', 'TUN', 'THA', 'TWN', 'CHE',
#        'SWE', 'ESP', 'KOR', 'ZAF', 'SVN', 'SVK', 'SGP', 'SRB', 'SAU',
#        'RUS', 'QAT', 'PRT', 'POL', 'PHL', 'PAK', 'NOR', 'NZL', 'NLD',
#        'MAR', 'MEX', 'MYS', 'MAC', 'LUX', 'LTU', 'LBN', 'LVA', 'KWT',
#        'JOR', 'JPN', 'ITA', 'ISR', 'IRL', 'IRN', 'IDN', 'IND', 'HUN',
#        'HKG', 'GRC', 'DEU', 'FRA', 'FIN', 'EST', 'EGY', 'DNK', 'CZE',
#        'CYP', 'HRV', 'COL', 'CHN', 'BGD', 'CHL', 'CAN', 'BRA', 'BEL',
#        'AUT', 'AUS', 'DZA', 'URY', 'ISL', 'ARG', 'BGR', 'ROU', 'NGA',
#        'UGA', 'GHA', 'ECU', 'VEN', 'MUS', 'VNM', 'ZMB', 'TZA', 'LKA',
#        'AND', 'AFG', 'ALB', 'ARM', 'BIH', 'BFA', 'BHR', 'BEN', 'BRN',
#        'BOL', 'BHS', 'BLZ', 'CAF', 'CIV', 'CMR', 'CRI', 'CUB', 'DJI',
#        'DOM', 'ERI', 'ETH', 'GAB', 'GIN', 'GTM', 'GUY', 'HND', 'HTI',
#        'KEN', 'KGZ', 'KHM', 'KAZ', 'LAO', 'LBR', 'LSO', 'LBY', 'MNE',
# ...

# %%
uni.describe()
# Out:
#                 ID
# count  5891.000000
# mean   3100.581395
# std    1821.125181
# min       1.000000
# 25%    1494.500000
# 50%    3068.000000
# 75%    4701.500000
# max    6234.000000

# %%
uniNGA = uni.groupby('country code')

# %%
uniNGA.get_group('NGA').nunique()
# Out:
# ID                  112
# university names    112
# country code          1
# dtype: int64

# %%
uniNGA.get_group('NGA').nunique()
# Out:
# ID                  112
# university names    112
# country code          1
# dtype: int64

# %%
plt.figure(figsize = (15,30))
sns.countplot(y='country code',data=uni)
